# %%
# %pip install davos
import davos

davos.config.suppress_stdout = True
# Out:
# Requirement already satisfied: davos in /Users/jmanning/opt/anaconda3/envs/attention-memory/lib/python3.10/site-packages (0.1.1)
# Requirement already satisfied: packaging in /Users/jmanning/opt/anaconda3/envs/attention-memory/lib/python3.10/site-packages (from davos) (21.3)
# Requirement already satisfied: setuptools in /Users/jmanning/opt/anaconda3/envs/attention-memory/lib/python3.10/site-packages (from davos) (65.6.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/jmanning/opt/anaconda3/envs/attention-memory/lib/python3.10/site-packages (from packaging->davos) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
smuggle numpy as np               # pip: numpy==1.24.2
smuggle pandas as pd              # pip: pandas==1.5.3
from tqdm smuggle tqdm            # pip: tqdm==4.64.1

# needed to get helpers to run
smuggle matplotlib                # pip: matplotlib==3.7.0
smuggle requests                  # pip: requests==2.28.2
smuggle future                    # pip: future==0.18.3

from glob import glob as lsdir
import os
import pickle

from helpers import download_data, datadir

# %% [markdown]
# Download the dataset and load in pre- and post-experimental questionnaire responses

# %%
download_data()

preexperimental_fnames = lsdir(os.path.join(datadir, '*', '*', 'pre_questionnaire_*.pkl'))
postexperimental_fnames = lsdir(os.path.join(datadir, '*', '*', 'post_questionnaire_*.pkl'))

preexperimental_questions = ['Age', 'Gender', 
                             'Hispanic or Latino', 
                             'White', 'Black or African American', 'Native Hawaiian or other Pacific Islander', 'Asian', 'American Indian or Alaska Native', 'Other race', 'Decline to specify race',
                             'Highest degree',
                             'Reading impairments',
                             'Normal color vision',
                             'Medications or injuries',
                             'Meds or injuries details',
                             'Hours of sleep',
                             'Cups of coffee',
                             'Alertness']

postexperimental_questions = ['Engagement', 'Tiredness', 'Easier to remember (category)', 'Easier to remember (side)', 'Strategies']

# %%
def load_pre(fname):
    with open(fname, 'rb') as f:
        pre = pickle.load(f)
    
    return pd.Series({k: v for k, v in zip(preexperimental_questions, pre)}).to_frame().T

def load_post(fname):
    with open(fname, 'rb') as f:
        post = pickle.load(f)
    
    return pd.Series({k: v for k, v in zip(postexperimental_questions, post)}).to_frame().T

# %%
pre = pd.concat([load_pre(fname) for fname in preexperimental_fnames])
post = pd.concat([load_post(fname) for fname in postexperimental_fnames])

# %%
pre.head()
# Out:
#    Age  Gender Hispanic or Latino  White Black or African American  \
# 0  21   Female                 No  False                     False
# 0   18  Female                 No   True                     False
# 0   21    Male                Yes   True                     False
# 0   19  Female                 No   True                     False
# 0   19  Female                 No  False                     False
#
#   Native Hawaiian or other Pacific Islander  Asian  \
# 0                                     False   True
# 0                                     False  False
# 0                                     False  False
# 0                                     False  False
# 0                                     False   True
#
#   American Indian or Alaska Native Other race Decline to specify race  \
# 0                            False      False                   False
# 0                            False      False                   False
# 0                            False      False                   False
# 0                            False      False                   False
# 0                            False      False                   False
#
#   Highest degree Reading impairments Normal color vision  \
# 0   some college                  No                 Yes
# 0   some college                  No                 Yes
# 0   some college                  No                  No
# 0   some college                  No                 Yes
# 0   some college                  No                 Yes
#
#   Medications or injuries Meds or injuries details Hours of sleep  \
# 0                      No                                       5
# 0                      No                                     8.5
# 0                      No                                       6
# 0                      No                                       9
# 0                      No                                       5
#
#   Cups of coffee           Alertness
# 0              0  A little slugglish
# 0              0  A little slugglish
# 0              2          Very alert
# 0              0      A little alert
# 0              0             Neutral

# %%
post.head()
# Out:
#         Engagement       Tiredness  \
# 0          Neutral         Neutral
# 0          Neutral      Very tired
# 0          Neutral  A little tired
# 0  A little boring         Neutral
# 0               --              --
#
#                        Easier to remember (category)  \
# 0
# 0  the scene because it had more distinct charact...
# 0  landscapes werre much easier to recall. I thin...
# 0  The scenes, because the faces tended to blur t...
# 0
#
#                            Easier to remember (side)  \
# 0
# 0                                   I don't think so
# 0                                                no
# 0  Maybe L was a little easier. But I don't think...
# 0
#
#                                           Strategies
# 0
# 0  I would try to pick out one distinct thing I s...
# 0          tried whispering to myaelf a key feature
# 0  I would repeat characteristics about the scene...
# 0

# %% [markdown]
# # Age

# %%
pre[['Age']].astype('float').describe()
# Out:
#              Age
# count  53.000000
# mean   18.735849
# std     0.812189
# min    18.000000
# 25%    18.000000
# 50%    19.000000
# 75%    19.000000
# max    21.000000

# %% [markdown]
# # Gender

# %%
pd.DataFrame(pre[['Gender']].value_counts())
# Out:
#          0
# Gender
# Female  34
# Male    18
# --       1

# %% [markdown]
# # Ethnicity and race

# %%
ethnicity_cols = ['Hispanic or Latino']
race_cols = ['White', 'Black or African American', 'Native Hawaiian or other Pacific Islander', 'Asian', 'American Indian or Alaska Native', 'Other race', 'Decline to specify race']

pd.DataFrame(pre[ethnicity_cols].value_counts())
# Out:
#                      0
# Hispanic or Latino
# No                  44
# Yes                  7
# --                   2

# %%
pd.DataFrame(pre[race_cols].sum(axis=0))
# Out:
#                                             0
# White                                      37
# Black or African American                   2
# Native Hawaiian or other Pacific Islander   0
# Asian                                      13
# American Indian or Alaska Native            4
# Other race                                  1
# Decline to specify race                     0

# %% [markdown]
# # Education

# %%
pd.DataFrame(pre[['Highest degree']].value_counts())
# Out:
#                        0
# Highest degree
# some college          32
# high school graduate  21

# %% [markdown]
# # Medical information

# %%
pd.DataFrame(pre['Reading impairments'].value_counts())
# Out:
#      Reading impairments
# No                    49
# Yes                    4

# %%
pd.DataFrame(pre['Normal color vision'].value_counts())
# Out:
#      Normal color vision
# Yes                   50
# No                     3

# %%
pd.DataFrame(pre['Medications or injuries'].value_counts())
# Out:
#      Medications or injuries
# No                        50
# Yes                        3

# %%
pd.DataFrame(pre['Meds or injuries details'].value_counts())
# Out:
#                                                 Meds or injuries details
#                                                                       49
# recently hit my head very hard                                         1
# n/a                                                                    1
# I am take concerta but am not on it right now                          1
# Amphetamine (though not at time of experiment)                         1

# %% [markdown]
# # Sleep, alertness, and coffee consumption

# %%
pd.DataFrame(pre['Hours of sleep'].astype('float').describe())
# Out:
#        Hours of sleep
# count       53.000000
# mean         6.867925
# std          1.305134
# min          4.000000
# 25%          6.000000
# 50%          7.000000
# 75%          8.000000
# max          9.000000

# %%
pd.DataFrame(pre['Cups of coffee'].astype('float').describe())
# Out:
#        Cups of coffee
# count       53.000000
# mean         0.330189
# std          0.545466
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          2.000000

# %%
alertness_dict = {'Very alert': 5, 'A little alert': 4, 'Neutral': 3, 'A little sluggish': 2, 'Very sluggish': 1}
pd.DataFrame(pre['Alertness'].map(alertness_dict).describe())
# Out:
#        Alertness
# count  43.000000
# mean    3.441860
# std     0.958727
# min     1.000000
# 25%     3.000000
# 50%     3.000000
# 75%     4.000000
# max     5.000000

# %%
pd.DataFrame(pre['Alertness'].value_counts())
# Out:
#                     Alertness
# Neutral                    20
# A little alert             15
# A little slugglish         10
# Very alert                  5
# Very sluggish               3
